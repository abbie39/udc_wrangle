# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
import pandas as pd
import requests

# %%
import tweepy

# %%
# importing csv as a DataFrame
df = pd.read_csv('twitter-archive-enhanced.csv')
# checking the DataFrame has been created correctly
display(df.head())
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
# Downloading file image-predictions.tsv from cloudfront url supplied by Udacity
url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
response=requests.get(url)
with open("image-predictions.tsv", mode="wb") as file:
    file.write(response.content)

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt). Cannot connect to twitter API due to new restrictions on free API tier imposed by X.

# %%
# Connect to twitter API
# consumer_key = '' 
# consumer_secret = '' 
# access_token = '' 
# access_secret = '' 
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
# auth.set_access_token(access_token, access_secret) 
# api = tweepy.API(auth)

# %%
# # Write each tweet to JSON file
# id_of_tweet=892420643555336193
# tweet = api.get_status(id_of_tweet)
# print(tweet.text)
# The new X/Twitter API v2 does not allow you to read tweets (you can only write) so I will have to download 
# the JSON file from udacity instead

# %%
# read JSON file into a pandas dataframe
tweets_json_all=pd.read_json('tweet-json.txt', lines=True)
# checking JSON has been read in correctly
display(tweets_json_all.head())
print(tweets_json_all.shape)
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                                                                                                                                             full_text  \
# 0                                                       This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# 1  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# ...

# %%
# checking names of all the columns
tweets_json_all.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'extended_entities', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'possibly_sensitive',
#        'possibly_sensitive_appealable', 'lang', 'retweeted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status'],
#       dtype='object')

# %%
# creating a dataframe that subsets the columns we are interested in 
tweets_json=tweets_json_all[['id', 'retweet_count', 'favorite_count']]
# checking this dataframe has been created correctly
display(tweets_json.head())
print(tweets_json.shape)
# has the same number of rows as the original tweets_json_all df
# has the 3 columns we are interested in
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048
# (2354, 3)

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# ## Visual assessment
# First explore the dataframe to identify any issues

# %%
# Explore dataframe visually in Excel
# Show dataframe in python for further visual assessment
df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# <p>Tidy data is when each variable forms a column, each observation forms a row and each observational unit forms a table.
#     </p>
# <p>**Tidiness issue**: the final 4 columns 'doggo', 'floofer', 'pupper', 'puppo' could be combined to be one column if we can check that no tweet ever refers to a dog as more than one of these (i.e. they are mutually exclusive).<br>
#    **Tidiness issue**: Retweets should be in a separate dataframe.<br>
#     **Quality issue**: Some values in the 'name' column do not make sense, e.g. the value 'a' as name for rows 2352-2354.
#     </p>
# <p>It seems that if a tweet is a retweet then it will have a value in the retweeted_status_id, retweeted_status_user_id and retweeted_status_timestamp.
# Let's investigate further these retweets, and the values in 'doggo', 'floofer', 'pupper', 'puppo' columns through **programmatic assessment**.
#     </p>

# %% [markdown]
# ## Programmatic assessment

# %%
# find all records of tweets that are retweets
df_retweets=df[~df['retweeted_status_id'].isnull()]
display(df_retweets.head())
# we can also note all text in a retweet seems to start with RT, let's verify
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19  888202515573088257                    NaN                  NaN
# 32  886054160059072513                    NaN                  NaN
# 36  885311592912609280                    NaN                  NaN
# 68  879130579576475649                    NaN                  NaN
# 73  878404777348136964                    NaN                  NaN
#
#                     timestamp  \
# 19  2017-07-21 01:02:36 +0000
# 32  2017-07-15 02:45:48 +0000
# 36  2017-07-13 01:35:06 +0000
# 68  2017-06-26 00:13:58 +0000
# 73  2017-06-24 00:09:53 +0000
#
#                                                                                 source  \
# 19  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 32  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 36  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
# verify all retweets text values start with RT
len(df_retweets[df_retweets['text'].str.startswith("RT")])-len(df_retweets)
# Out:
# 0

# %%
# check that only one of 'doggo', 'floofer', 'pupper', 'puppo' will be populated for each record
df[['doggo', 'floofer', 'pupper', 'puppo']].notnull().value_counts()
# Out:
# doggo  floofer  pupper  puppo
# False  False    False   False    1976
#                 True    False     245
# True   False    False   False      83
# False  False    False   True       29
# True   False    True    False      12
# False  True     False   False       9
# True   False    False   True        1
#        True     False   False       1
# Name: count, dtype: int64

# %% [markdown]
# There are 1976 cases where all of doggo, floofer, pupper and puppo are null. <br>
# There are 12 cases where a dog is both a doggo and pupper. <br>
# There is 1 case where a dog is both a doggo and fluffer.

# %%
# Investigate data types
display(df.dtypes)
display(tweets_json.dtypes)
# id is an integer in both tables
# Out:
# tweet_id                        int64
# in_reply_to_status_id         float64
# in_reply_to_user_id           float64
# timestamp                      object
# source                         object
# text                           object
# retweeted_status_id           float64
# retweeted_status_user_id      float64
# retweeted_status_timestamp     object
# expanded_urls                  object
# rating_numerator                int64
# rating_denominator              int64
# name                           object
# doggo                          object
# floofer                        object
# pupper                         object
# puppo                          object
# dtype: object
# id                int64
# retweet_count     int64
# favorite_count    int64
# dtype: object

# %%
# investigate null values
print(df.info())
# name has 2356-1611=745 null values
# expanded_urls has 59 null values, this is a small amount and we do not have access to expand urls so will be left
# rating_numerator and rating_denominator are populated for all tweets so they are all ratings
# timestamp and retweeted_status_timestamp are not in datetime format
# from in_reply_to_status_id and retweeted_status_id we can see 78 tweets are replies and 181 are retweets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        1611 non-null   object
# ...

# %%
# investigate null values
tweets_json.info()
# tweets_json has no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
# investigate names
df['name'].unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', nan, 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'such',
#        'Maya', 'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey',
#        'Lilly', 'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella',
#        'Grizzwald', 'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey',
#        'Gary', 'a', 'Elliot', 'Louis', 'Jesse', 'Romeo', 'Bailey',
#        'Duddles', 'Jack', 'Emmy', 'Steven', 'Beau', 'Snoopy', 'Shadow',
#        'Terrance', 'Aja', 'Penny', 'Dante', 'Nelly', 'Ginger', 'Benedict',
#        'Venti', 'Goose', 'Nugget', 'Cash', 'Coco', 'Jed', 'Sebastian',
#        'Walter', 'Sierra', 'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover',
#        'Napolean', 'Dawn', 'Boomer', 'Cody', 'Rumble', 'Clifford',
#        'quite', 'Dewey', 'Scout', 'Gizmo', 'Cooper', 'Harold', 'Shikha',
# ...

# %%
# investigate values in nickname columns
display(df['doggo'].unique())
display(df['floofer'].unique())
display(df['pupper'].unique())
display(df['puppo'].unique())
# Out:
# array([nan, 'doggo'], dtype=object)
# array([nan, 'floofer'], dtype=object)
# array([nan, 'pupper'], dtype=object)
# array([nan, 'puppo'], dtype=object)

# %% [markdown]
# ### Quality issues
# 1. Some values in the 'name' column do not make sense, e.g. the value 'a' as name for rows 2352-2354, or values 'this' and 'unacceptable', one of the names even has a numeric value 'O'.
#
# 2. Name has a lot of null values (745 nulls)
#
# 3. Timestamp is an object but should be Date and Time (if split into two columns) or DateTime format (if in one column)
#
# 4. 78 tweets are replies - replies should be excluded.
#
# 5. 181 tweets are retweets - retweets should be excluded.
#
# 6. tweet_id (in df) should be an object not integer since it represents ID values so do not need to be treated as numbers.
#
# 7. in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id should all be objects not float values since they are ID values so do not need to be treated as numbers.
#
# 8. id in (tweets_json) should be an object not integer since it represents ID values so do not need to be treated as numbers.

# %% [markdown]
# ### Tidiness issues
# 1.The final 4 columns 'doggo', 'floofer', 'pupper', 'puppo' are values of a variable, thus should not be separate columns.
#
# 2.Datetime column contains both date and time.
#
# 3.'source' column contains both URL and also source value in text.

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
df_clean=df.copy()
tweets_json_clean=tweets_json.copy()

# %% [markdown]
# ### Issue #1: 5. 78 tweets are replies - replies should be excluded.

# %% [markdown]
# #### Define: Filter the dataframe to remove all records which have values in the 'in_reply_to_status_id' column.

# %% [markdown]
# #### Code

# %%
# create a cleaned dataframe with replies excluded
df_clean=df_clean[df_clean['in_reply_to_status_id'].isnull()]

# %% [markdown]
# #### Test

# %%
# check dataframe visually
df_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
# check for any records where in_reply_to_status_id is not null
df_clean['in_reply_to_status_id'].notnull().value_counts()
# Out:
# in_reply_to_status_id
# False    2278
# Name: count, dtype: int64

# %% [markdown]
# There are no records where 'in_reply_to_status_id' is not null, hence we can be confident we have filtered out all replies.

# %% [markdown]
# ### Issue #2: 181 tweets are retweets - retweets should be excluded.

# %% [markdown]
# #### Define: Filter the dataframe to remove all records which have values in the 'retweeted_status_id' column.

# %% [markdown]
# #### Code

# %%
# create a cleaned dataframe with retweets excluded
df_clean=df_clean[df_clean['retweeted_status_id'].isnull()]

# %% [markdown]
# #### Test

# %%
# check dataframe visually 
df_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
# check for any records where retweeted_status_id is not null
df_clean['retweeted_status_id'].notnull().value_counts()
# Out:
# retweeted_status_id
# False    2097
# Name: count, dtype: int64

# %% [markdown]
# There are no records where 'retweeted_status_id' is not null, hence we can be confident we have filtered out all retweets.

# %% [markdown]
# ### Issue #3: Retweets and replies columns need to be dropped.

# %% [markdown]
# #### Define: Since we have dropped all retweets and replies, we should also drop the columns relating to them: 'in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'.  Thus we no longer need to convert from float values to objects (issue 7 above)

# %% [markdown]
# #### Code

# %%
# check all the replies and retweets columns are null 
df_clean[['in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 
       'retweeted_status_timestamp']].notnull().value_counts()
# all values are null in these columns so we are okay to drop them.
# Out:
# in_reply_to_status_id  in_reply_to_user_id  retweeted_status_id  retweeted_status_user_id  retweeted_status_timestamp
# False                  False                False                False                     False                         2097
# Name: count, dtype: int64

# %%
df_clean=df_clean.drop(['in_reply_to_status_id', 
                       'in_reply_to_user_id', 'retweeted_status_id', 
                       'retweeted_status_user_id', 'retweeted_status_timestamp'], axis=1)

# %% [markdown]
# #### Test

# %%
# check the columns have been dropped
df_clean.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# ### Issue #4: tweet_id values should be converted to objects.

# %% [markdown]
# #### Define: tweet_id (in df) should be an object not integer since it represents ID values so do not need to be treated as numbers. Using astype(str), cast this field to contain string objects.

# %% [markdown]
# #### Code

# %%
# store the number of null values in tweet_id column before making any transformation
df_id_nulls=df_clean['tweet_id'].isnull().value_counts()

# %%
# Convert tweet_id to a string
df_clean['tweet_id']=df_clean['tweet_id'].astype(str)

# %% [markdown]
# #### Test

# %%
# check tweet_id is now a string
df_clean.dtypes
# Out:
# tweet_id              object
# timestamp             object
# source                object
# text                  object
# expanded_urls         object
# rating_numerator       int64
# rating_denominator     int64
# name                  object
# doggo                 object
# floofer               object
# pupper                object
# puppo                 object
# dtype: object

# %%
# check head of the data to ensure id is still populated
df_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %%
# check number of null values is the same as before the conversion
df_id_nulls-df_clean['tweet_id'].isnull().value_counts()
# Out:
# tweet_id
# False    0
# Name: count, dtype: int64

# %% [markdown]
# ### Issue #5: id values should be converted to objects

# %% [markdown]
# #### Define: id (in tweets_json) should be an object not integer since it represents ID values so do not need to be treated as numbers. Using .astype(str), cast this field to be string objects.

# %% [markdown]
# #### Code

# %%
# Convert id to a string
tweets_json_clean['id']=tweets_json_clean['id'].astype(str)

# %% [markdown]
# #### Test

# %%
# check id is now a string
tweets_json_clean.dtypes
# Out:
# id                object
# retweet_count      int64
# favorite_count     int64
# dtype: object

# %%
# check head of data to ensure id field is still populated
tweets_json_clean.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
# check number of null values in id column is same
tweets_json['id'].isnull().value_counts()- tweets_json_clean['id'].isnull().value_counts()
# Out:
# id
# False    0
# Name: count, dtype: int64

# %% [markdown]
# ### Issue #6: timestamp column is not in date / time format

# %% [markdown]
# #### Define: First we will convert timestamp to datetime format using pd.to_datetime(). Then we will split this value out into two separate columns to address tidiness issues, the two columns will be: 'date' and 'time'.  This will be achieved by accessing the elements of the datetime data.

# %% [markdown]
# #### Code

# %%
# convert to datetime format
df_clean['timestamp']=pd.to_datetime(df_clean['timestamp'])

# %%
df_clean.dtypes
# Out:
# tweet_id                           object
# timestamp             datetime64[ns, UTC]
# source                             object
# text                               object
# expanded_urls                      object
# rating_numerator                    int64
# rating_denominator                  int64
# name                               object
# doggo                              object
# floofer                            object
# pupper                             object
# puppo                              object
# dtype: object

# %%
# create new columns for 'date' and 'time'
df_clean["date"]=df_clean['timestamp'].dt.date
df_clean["time"]=df_clean['timestamp'].dt.time
# check columns have been created and their datatypes
display(df_clean.head())
df_clean.dtypes
# Out:
#              tweet_id                 timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00
# 1  892177421306343426 2017-08-01 00:17:27+00:00
# 2  891815181378084864 2017-07-31 00:18:03+00:00
# 3  891689557279858688 2017-07-30 15:58:51+00:00
# 4  891327558926688256 2017-07-29 16:00:24+00:00
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %%
# drop timestamp column
df_clean=df_clean.drop('timestamp', axis=1)

# %% [markdown]
# #### Test

# %%
# visually assess the dataframe columns
df_clean[['date', 'time']]
# Out:
#             date      time
# 0     2017-08-01  16:23:56
# 1     2017-08-01  00:17:27
# 2     2017-07-31  00:18:03
# 3     2017-07-30  15:58:51
# 4     2017-07-29  16:00:24
# ...          ...       ...
# 2351  2015-11-16  00:24:50
# 2352  2015-11-16  00:04:52
# 2353  2015-11-15  23:21:54
# 2354  2015-11-15  23:05:30
# 2355  2015-11-15  22:32:08
#
# [2097 rows x 2 columns]

# %%
# check timestamp column has been dropped
df_clean.columns
# Out:
# Index(['tweet_id', 'source', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'date', 'time'],
#       dtype='object')

# %% [markdown]
# ### Issue #7: Name values contain a lot of nulls

# %% [markdown]
# #### Define: look to extract name value from text column by searching for key words such as 'name', 'named' and 'called'.

# %% [markdown]
# #### Code

# %%
# Investigate the text values where we have no name to see if we can pull out a name
df_no_name=df_clean[df_clean['name'].isnull()==True]

# %%
# investigate if we can find any references to 'called', 'named' or 'name'
lst = ['called', 'named', 'name']
df_possible_name=df_no_name[df_no_name['text'].str.contains('|'.join(lst), na=False)]

# df_no_name[df_no_name['text'].str.contains('called')]
# df_no_name[df_no_name['text'].str.contains('named')]
# df_no_name[df_no_name['text'].str.contains('name')]

# %%
# investigate if we can pull the names from here
pd.set_option('display.max_colwidth', None)
display(df_possible_name[['tweet_id', 'text', 'name']])
# Out:
#                 tweet_id  \
# 35    885518971528720385
# 168   859607811541651456
# 1596  686286779679375361
# 1678  682047327939461121
# 1734  679736210798047232
# 2086  670803562457407488
# 2166  669363888236994561
# 2227  668268907921326080
# 2267  667524857454854144
# 2269  667509364010450944
# 2305  666837028449972224
# 2306  666835007768551424
#
#                                                                                                                                                                   text  \
# 35                                                                                             I have a new hero and his name is Howard. 14/10 https://t.co/gzLHboL7Sk
# 168   Sorry for the lack of posts today. I came home from school and had to spend quality time with my puppo. Her name is Zoey and she's 13/10 https://t.co/BArWupFAn0
# ...

# %%
# split strings on the following substrings 'named', 'name is' 
# the following tweet id's use 'name is': 885518971528720385, 859607811541651456, 
# 682047327939461121, 679736210798047232, 667524857454854144
# the index values are: [35, 168, 1678, 1734, 2267]
# the following tweet id's use 'named': 669363888236994561, 668268907921326080, 667509364010450944
# the index values are: [2166, 2227, 2269]

# %%
# populate name column with value after 'name is '. Print names to check they make sense
name_is_lst=[35, 168, 1678, 1734, 2267]
for i in name_is_lst:
    string=(df_clean['text'][i].split("name is ",1)[1]).split(" ",1)[0].strip("!\"#\$%&\'\(\)\*\+,-\./:;<=>\?@\[\\\]\^_`{\|}~")
    df_clean['name'].loc[i]=string
    print(string)
# populate name column with value after 'named '. Print names to check they make sense.
named_lst=[2166, 2227, 2269]
for i in named_lst:
    string=(df_clean['text'][i].split("named ",1)[1]).split(" ",1)[0].strip("!\"#\$%&\'\(\)\*\+,-\./:;<=>\?@\[\\\]\^_`{\|}~")
    df_clean['name'].loc[i]=string
    print(string)
# Out:
# Howard
# Zoey
# Thea
# Sabertooth
# Big
# Zeus
# Guss
# Tickles
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/87595790.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'].loc[i]=string
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/87595790.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'].loc[i]=string
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/87595790.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# need to manually change the value at index 2267 from 'Big' to 'Big Jumpy Rat'
df_clean['name'].loc[2267]='Big Jumpy Rat'
df_clean['name'].loc[2267]
# Out:
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/2892226873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'].loc[2267]='Big Jumpy Rat'
# 'Big Jumpy Rat'

# %% [markdown]
# Some values in name are null, and that is due to text not containing a name. It will not be possible to extract a name for these values.

# %% [markdown]
# #### Test

# %%
# check that names for relevant tweet id's have updated
tweet_ids=['885518971528720385', '859607811541651456', 
           '682047327939461121', '679736210798047232', '667524857454854144',
          '669363888236994561', '668268907921326080', '667509364010450944']
df_clean.loc[df_clean['tweet_id'].isin(tweet_ids)]
# Out:
#                 tweet_id  \
# 35    885518971528720385
# 168   859607811541651456
# 1678  682047327939461121
# 1734  679736210798047232
# 2166  669363888236994561
# 2227  668268907921326080
# 2267  667524857454854144
# 2269  667509364010450944
#
#                                                                                   source  \
# 35    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 168   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1678  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1734  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2166  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2227  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2267                  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# ...

# %% [markdown]
# ### Issue #8: Some name values do not make sense

# %% [markdown]
# #### Define: Look for name values that are just a single letter by ordering name by minimum length. Gather a list of index values and tweet id's for the tweets with the smallest values in 'name' column. Compare with text column and replace with name if possible, if not then replace with a null value.

# %% [markdown]
# #### Code

# %%
# sort by length of name
df_clean.name.str.len().sort_values()
# Out:
# 2354    1.0
# 1049    1.0
# 2153    1.0
# 2146    1.0
# 2128    1.0
#        ...
# 2342    NaN
# 2343    NaN
# 2344    NaN
# 2351    NaN
# 2355    NaN
# Name: name, Length: 2097, dtype: float64

# %%
# we decide a name must be at least 2 characters so we want to investigate all values where name is length 1
df_short_names=df_clean[df_clean.name.str.len()==1.0]
# save index values
short_names_lst=list(df_short_names.index.values)

# %%
# investigate if we can pull the names from here
pd.set_option('display.max_colwidth', None)
display(df_short_names[['tweet_id', 'text', 'name']])
# it appears the reason a lot of columns have the name 'a' is because the Name has been calculated by taking 
# the word that follows 'This is' assuming it would be 'This is Rex' rather than 'This is a sausage dog' as 
# is the case with a lot of entries.
# index 775 is the only case where This is.. is followed by the name (in this case O'Malley)
# Out:
#                 tweet_id  \
# 56    881536004380872706
# 649   792913359805018113
# 775   776201521193218049
# 801   772581559778025472
# 1002  747885874273214464
# 1004  747816857231626240
# 1017  746872823977771008
# 1049  743222593470234624
# 1193  717537687239008257
# 1207  715733265223708672
# 1340  704859558691414016
# 1351  704054845121142784
# 1361  703079050210877440
# 1368  702539513671897089
# 1382  700864154249383937
# 1499  692187005137076224
# 1737  679530280114372609
# 1785  677644091929329666
# 1853  675706639471788032
# 1854  675534494439489536
# 1877  675109292475830276
# 1878  675047298674663426
# 1923  674082852460433408
# 1941  673715861853720576
# 1955  673636718965334016
# 1994  672604026190569472
# 2034  671743150407421952
# 2066  671147085991960577
# 2116  670427002554466305
# 2125  670361874861563904
# 2128  670303360680108032
# 2146  669923323644657664
# 2153  669661792646373376
# 2161  669564461267722241
# 2191  668955713004314625
# ...

# %%
# populate name column with value after 'name is '. Print names to check they make sense.
for i in short_names_lst:
    if 'name is' in df_clean['text'][i]:
        string=(df_clean['text'][i].split("name is ",1)[1]).split(" ",1)[0].strip("!\"#\$%&\'\(\)\*\+,-\./:;<=>\?@\[\\\]\^_`{\|}~")
        df_clean['name'].loc[i]=string
        print(string)
# populate name column with value after 'named '. Print names to check they make sense.
for i in short_names_lst:
    if 'named' in df_clean['text'][i]:
        string=(df_clean['text'][i].split("named ",1)[1]).split(" ",1)[0].strip("!\"#\$%&\'\(\)\*\+,-\./:;<=>\?@\[\\\]\^_`{\|}~")
        df_clean['name'].loc[i]=string
        print(string)
# Out:
# Daryl
# Wylie
# Kip
# Jacob
# Rufus
# Spork
# Cherokee
# Hemry
# Alphred
# Alfredo
# Leroi
# Chuk
# Alfonso
# Cheryl
# Jessiga
# Klint
# Kohl
# Pepe
# Octaviath
# Johm
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/4275551141.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'].loc[i]=string
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/4275551141.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'].loc[i]=string
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/4275551141.py:11: SettingWithCopyWarning:
# ...

# %%
# manually fix value for index row 775, where the name should be "O'Malley"
df_clean['name'].loc[775]="O'Malley"
# Out:
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/3626010438.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'].loc[775]="O'Malley"

# %%
# find rows where name value is still a and replace with NaN
for i in short_names_lst:
    if df_clean['name'][i]=='a':
        #string=(df_clean['text'][i].split("name is ",1)[1]).split(" ",1)[0].strip("!\"#\$%&\'\(\)\*\+,-\./:;<=>\?@\[\\\]\^_`{\|}~")
        #df_clean['name'].loc[i]=string
        df_clean['name'][i]='NaN'
        print(df_clean['name'][i])
# Out:
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/1976451647.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'][i]='NaN'
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/1976451647.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['name'][i]='NaN'
# ...

# %% [markdown]
# #### Test

# %%
# check for relevant index values
df_clean.loc[short_names_lst]
# Out:
#                 tweet_id  \
# 56    881536004380872706
# 649   792913359805018113
# 775   776201521193218049
# 801   772581559778025472
# 1002  747885874273214464
# 1004  747816857231626240
# 1017  746872823977771008
# 1049  743222593470234624
# 1193  717537687239008257
# 1207  715733265223708672
# 1340  704859558691414016
# 1351  704054845121142784
# 1361  703079050210877440
# 1368  702539513671897089
# 1382  700864154249383937
# 1499  692187005137076224
# 1737  679530280114372609
# 1785  677644091929329666
# 1853  675706639471788032
# 1854  675534494439489536
# 1877  675109292475830276
# 1878  675047298674663426
# 1923  674082852460433408
# 1941  673715861853720576
# 1955  673636718965334016
# 1994  672604026190569472
# 2034  671743150407421952
# 2066  671147085991960577
# 2116  670427002554466305
# 2125  670361874861563904
# 2128  670303360680108032
# 2146  669923323644657664
# 2153  669661792646373376
# 2161  669564461267722241
# 2191  668955713004314625
# ...

# %% [markdown]
# ### Issue #9: 'source' column contains both URL and also source value in text.

# %% [markdown]
# #### Define: split 'source' column into 'source_value' and 'source_url' using str.split()

# %% [markdown]
# #### Code

# %%
# create empty columns for source_url and source_value
df_clean['source_url']='NaN'
df_clean['source_value']='NaN'

# %%
for i in range(df_clean.shape[0]):
    link=df_clean['source'].iloc[i].split('"')[1]
    txt=df_clean['source'].iloc[i].split('"')[4].split(">")[1].split("<")[0]
    df_clean['source_url'].iloc[i]=link
    df_clean['source_value'].iloc[i]=txt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'source'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# drop the original source column
df_clean=df_clean.drop('source', axis=1)

# %% [markdown]
# #### Test

# %%
# check new source columns exist
df_clean.sample(10)
# Out:
#                 tweet_id  \
# 278   840268004936019968
# 947   752519690950500352
# 45    883482846933004288
# 1577  687399393394311168
# 1436  697255105972801536
# 1672  682389078323662849
# 1353  703769065844768768
# 1606  685667379192414208
# 1282  708738143638450176
# 1757  678764513869611008
#
#                                                                                                                                                                text  \
# 278   This is Monty. He makes instantly regrettable decisions. Couldn't help himself. It looked like a ghost lollipop. 12/10 mistake happen https://t.co/8Wsr6b4RjE
# 947                                                 Hopefully this puppo on a swing will help get you through your Monday. 11/10 would push https://t.co/G54yClasz2
# 45                         This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
# ...

# %%
# check unique values in new source columns
source_url_values=set(df_clean['source_url'])
source_text_values=set(df_clean['source_value'])
print(source_url_values,source_text_values)
# values fit expected values
# Out:
# {'http://twitter.com/download/iphone', 'NaN'} {'Twitter for iPhone', 'NaN'}

# %% [markdown]
# ### Issue #10: The final 4 columns 'doggo', 'floofer', 'pupper', 'puppo' are values of a variable, thus should not be separate columns.

# %% [markdown]
# #### Define: Create a new column called 'nickname' which can take values 'doggo', 'floofer', 'pupper', 'puppo'.

# %% [markdown]
# #### Code

# %%
# check that only one of 'doggo', 'floofer', 'pupper', 'puppo' will be populated for each record
df_clean[['doggo', 'floofer', 'pupper', 'puppo']].notnull().value_counts()
# Out:
# doggo  floofer  pupper  puppo
# False  False    False   False    1761
#                 True    False     221
# True   False    False   False      72
# False  False    False   True       23
#        True     False   False       9
# True   False    True    False       9
#                 False   True        1
#        True     False   False       1
# Name: count, dtype: int64

# %% [markdown]
# There are 1761 cases where all of doggo, floofer, pupper and puppo are null. <br>
# There are 9 cases where a dog is both a doggo and pupper. <br>

# %%
# create empty nickname column
df_clean['nickname']='NaN'

# %%
# update nickname values for all rows that have a nickname
for i in range(df_clean.shape[0]):
    if df_clean['doggo'].iloc[i]=='doggo' and df_clean['pupper'].iloc[i]=='pupper':
        nickname=['doggo', 'pupper']
        df_clean['nickname'].iloc[i]=nickname
    elif df_clean['doggo'].iloc[i]=='doggo':
        nickname='doggo'
        df_clean['nickname'].iloc[i]=nickname
    elif df_clean['floofer'].iloc[i]=='floofer':
        nickname='floofer'
        df_clean['nickname'].iloc[i]=nickname
    elif df_clean['pupper'].iloc[i]=='pupper':
        nickname='pupper'
        df_clean['nickname'].iloc[i]=nickname
    elif df_clean['puppo'].iloc[i]=='puppo':
        nickname='puppo'
        df_clean['nickname'].iloc[i]=nickname
# Out:
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/1079897231.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['nickname'].iloc[i]=nickname
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/1079897231.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['nickname'].iloc[i]=nickname
# /var/folders/br/p_v6q73s679_sn0crmrd9mtw0000gn/T/ipykernel_2099/1079897231.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# check nickname column has been created
df_clean.sample(10)
# Out:
#                 tweet_id  \
# 246   845677943972139009
# 436   820314633777061888
# 1146  727155742655025152
# 622   796080075804475393
# 1612  685321586178670592
# 1378  701570477911896070
# 1246  711694788429553666
# 620   796125600683540480
# 1868  675166823650848770
# 689   787717603741622272
#
#                                                                                                                                                                       text  \
# 246                      C'mon guys. Please only send in dogs. We only rate dogs, not Exceptional-Tongued Peruvian Floor Bears. Thank you... 12/10 https://t.co/z30iQLiXNo
# 436   We are proud to support @LoveYourMelon on their mission to put a hat on every kid battling cancer. They are 14/10\n\nhttps://t.co/XQlmPTLHPl https://t.co/ZNIkkHgtYE
# 1146                                       When you're trying to enjoy yourself but end up having to take care of your way too drunk friend. 11/10 https://t.co/BRkhj6tdN0
# ...

# %% [markdown]
# ### Test

# %%
# check nickname column has been created
df_clean.columns
# Out:
# Index(['tweet_id', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'date', 'time', 'source_url', 'source_value', 'nickname'],
#       dtype='object')

# %%
# check values in nickname column align with expectations
# all values should be zero
print(len(df_clean.loc[(df_clean['nickname']=='pupper') & (df_clean['pupper']=='NaN')]),
len(df_clean.loc[(df_clean['nickname']=='doggo') & (df_clean['doggo']=='NaN')]),
len(df_clean.loc[(df_clean['nickname']=='floofer') & (df_clean['floofer']=='NaN')]),
len(df_clean.loc[(df_clean['nickname']=='puppo') & (df_clean['puppo']=='NaN')]))
# Out:
# 0 0 0 0

# %%
# drop individual name columns
df_clean=df_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1)

# %%
# check updated column names
df_clean.columns
# Out:
# Index(['tweet_id', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'date', 'time', 'source_url',
#        'source_value', 'nickname'],
#       dtype='object')

# %%
# check nickname column type
df_clean.dtypes
# it is an object as expected
# Out:
# tweet_id              object
# text                  object
# expanded_urls         object
# rating_numerator       int64
# rating_denominator     int64
# name                  object
# date                  object
# time                  object
# source_url            object
# source_value          object
# nickname              object
# dtype: object

# %%
# check number of rows is still 2097
df_clean.shape[0]
# Out:
# 2097

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
# save cleaned dataframe
df_clean.to_csv('twitter_archive_master.csv', sep=',')
# save cleaned tweets_json file
tweets_json_clean.to_json('twitter_archive.json')

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
# Find how many unique dog names are in the set vs. how many total names
unique_names_no=len(set(df_clean['name'].tolist()))
all_names_no=len(df_clean['name'].tolist())
print('The number of dog names contained in the tweets is ' + str(all_names_no) 
      + '. The number of unique dog names is ' + str(unique_names_no) +'.')
# Out:
# The number of dog names contained in the tweets is 2097. The number of unique dog names is 978.

# %%
# Which tweet got the highest number of retweets
ordered_retweets=tweets_json_clean.sort_values('retweet_count', ascending=False)
ordered_retweets
# Out:
#                       id  retweet_count  favorite_count
# 1037  744234799360020481          79515          131075
# 259   842892208864923648          56625               0
# 533   807106840509214720          56625          107015
# 816   770743923962707968          52360               0
# 1077  739238157791694849          52360           75163
# ...                  ...            ...             ...
# 341   832088576586297345              3              72
# 112   870726314365509632              3             121
# 273   840698636975636481              3             197
# 1293  707983188426153984              2              52
# 290   838085839343206401              0             150
#
# [2354 rows x 3 columns]

# %%
print('The most retweeted tweet had a retweet count of ' + str(ordered_retweets.iloc[0]['retweet_count']) 
      + ' and it\'s tweet id was ' +str(ordered_retweets.iloc[0]['id']) +'.')
# Out:
# The most retweeted tweet had a retweet count of 79515 and it's tweet id was 744234799360020481.

# %%
# Find the content of the tweet with the most favourites
# Which tweet got the highest number of favourites
ordered_faves=tweets_json_clean.sort_values('favorite_count', ascending=False)
# save the number of favourites
number_of_faves=ordered_faves.iloc[0]['favorite_count']
# save the id of the most favourited tweet
id_of_most_faves=ordered_faves.iloc[0]['id']

# %%
# find text content of the most favourited tweet
content_of_most_faved=df_clean[df_clean['tweet_id']==id_of_most_faves]
content_of_most_faved=content_of_most_faved['text']
print('The most favourited tweet was ""' + str(content_of_most_faved) +'"". It achieved '
     + str(number_of_faves) + ' favourites.')
# Out:
# The most favourited tweet was ""413    Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc
# Name: text, dtype: object"". It achieved 132810 favourites.

# %% [markdown]
# ### Insights:
# 1.The number of dog names contained in the tweets is 2097. The number of unique dog names is 978.
#
# 2.The most retweeted tweet had a retweet count of 79515 and it's tweet id was 744234799360020481.
#
#
# 3.The most favourited tweet was "Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc" It achieved 132810 favourites.

# %% [markdown]
# ### Visualization
# Create a bar chart to show number of tweets with each nickname

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
doggo_count=len(df_clean[df_clean['nickname']=='doggo'])
doggo_count
# Out:
# 74

# %%
objects = ['doggo', 'floofer', 'pupper', 'puppo', 'doggo and pupper']
doggo_count=len(df_clean[df_clean['nickname']=='doggo'])
floofer_count=len(df_clean[df_clean['nickname']=='floofer'])
pupper_count=len(df_clean[df_clean['nickname']=='pupper'])
puppo_count=len(df_clean[df_clean['nickname']=='puppo'])
doggo_and_pupper_count=len(df_clean[df_clean['nickname']=="'doggo', 'pupper'"])
values = [doggo_count, floofer_count, pupper_count, puppo_count, doggo_and_pupper_count]

# %%
plt.bar(objects, values, align='center', alpha=0.5)
plt.ylabel('Count of nickname')
plt.xlabel('Nickname')
plt.title('Most popular nicknames')
plt.show()
